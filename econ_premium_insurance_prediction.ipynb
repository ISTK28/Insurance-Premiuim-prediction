# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Medicalpremium.csv')

# %%
df.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice
# 0                       0         25000
# 1                       0         29000
# 2                       1         23000
# 3                       2         28000
# 4                       1         23000

# %%
df.shape
# Out:
# (986, 11)

# %%
df.isna().sum()
# Out:
# Age                        0
# Diabetes                   0
# BloodPressureProblems      0
# AnyTransplants             0
# AnyChronicDiseases         0
# Height                     0
# Weight                     0
# KnownAllergies             0
# HistoryOfCancerInFamily    0
# NumberOfMajorSurgeries     0
# PremiumPrice               0
# dtype: int64

# %%
df.describe()
# Out:
#               Age    Diabetes  BloodPressureProblems  AnyTransplants  \
# count  986.000000  986.000000             986.000000      986.000000
# mean    41.745436    0.419878               0.468560        0.055781
# std     13.963371    0.493789               0.499264        0.229615
# min     18.000000    0.000000               0.000000        0.000000
# 25%     30.000000    0.000000               0.000000        0.000000
# 50%     42.000000    0.000000               0.000000        0.000000
# 75%     53.000000    1.000000               1.000000        0.000000
# max     66.000000    1.000000               1.000000        1.000000
#
#        AnyChronicDiseases      Height      Weight  KnownAllergies  \
# count          986.000000  986.000000  986.000000      986.000000
# mean             0.180527  168.182556   76.950304        0.215010
# std              0.384821   10.098155   14.265096        0.411038
# min              0.000000  145.000000   51.000000        0.000000
# 25%              0.000000  161.000000   67.000000        0.000000
# 50%              0.000000  168.000000   75.000000        0.000000
# 75%              0.000000  176.000000   87.000000        0.000000
# max              1.000000  188.000000  132.000000        1.000000
#
#        HistoryOfCancerInFamily  NumberOfMajorSurgeries  PremiumPrice
# count               986.000000              986.000000    986.000000
# mean                  0.117647                0.667343  24336.713996
# std                   0.322353                0.749205   6248.184382
# min                   0.000000                0.000000  15000.000000
# 25%                   0.000000                0.000000  21000.000000
# 50%                   0.000000                1.000000  23000.000000
# 75%                   0.000000                1.000000  28000.000000
# max                   1.000000                3.000000  40000.000000

# %% [markdown]
# ## **Performing EDA**

# %%
df.hist(bins=30, figsize=(15, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2218836550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2208e7c450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2208e35a50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2208de0b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2208dad690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2208d64c90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2208d29350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2208cdf890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2208e47850>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2208e478d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2208c0b2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2208c428d0>]],
#       dtype=object)

# %%
sns.displot(x='Age',data=df,aspect=10/6,kde=True)

# %%
sns.displot(x='PremiumPrice',data=df,aspect=10/6,kde=True)

# %%
pr_lab=['Low','Basic','Average','High','SuperHigh']
df['PremiumLabel']=pr_bins=pd.cut(df['PremiumPrice'],bins=5,labels=pr_lab,precision=0)

# %%
fig,ax=plt.subplots(figsize=(12,6))
sns.barplot(y='Age',x='PremiumLabel',data=df,ax=ax)

# %%
fig,ax=plt.subplots(figsize=(12,6))
sns.swarmplot(x='PremiumLabel',y='Age',data=df,ax=ax)

# %%
plt.figure(figsize=(14,8))
sns.heatmap(df.corr(), annot = True, cmap='coolwarm',linewidths=.1)
plt.title("Heatmap for correlation between columns")
plt.show()

# %%
X = df.drop(['PremiumPrice','PremiumLabel'],axis=1)
y = df.PremiumPrice

# %%
from sklearn.preprocessing import MinMaxScaler
scalar =  MinMaxScaler()
X.Age = scalar.fit_transform(X[['Age']])
X.Height = scalar.fit_transform(X[['Height']])
X.Weight = scalar.fit_transform(X[['Weight']])

# %%
X.head()
# Out:
#         Age  Diabetes  BloodPressureProblems  AnyTransplants  \
# 0  0.562500         0                      0               0
# 1  0.875000         1                      0               0
# 2  0.375000         1                      1               0
# 3  0.708333         1                      1               0
# 4  0.416667         0                      0               0
#
#    AnyChronicDiseases    Height    Weight  KnownAllergies  \
# 0                   0  0.232558  0.074074               0
# 1                   0  0.813953  0.271605               0
# 2                   0  0.302326  0.098765               0
# 3                   1  0.883721  0.518519               0
# 4                   1  0.488372  0.456790               0
#
#    HistoryOfCancerInFamily  NumberOfMajorSurgeries
# 0                        0                       0
# 1                        0                       0
# 2                        0                       1
# 3                        0                       2
# 4                        0                       1

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=43)

# %%
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRFRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
models = {
    LinearRegression():'Linear Regression',
    Lasso():'Lasso',
    XGBRFRegressor():'XGBRFRegressor',
    RandomForestRegressor():'RandomForest'
}
for m in models.keys():
    m.fit(X_train,y_train)
# Out:
# [07:08:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
for model,name in models.items():
     print(f"Accuracy Score for {name} is : ",model.score(X_test,y_test)*100,"%")
     pred = model.predict(X_test)
     print(f"R_square score for {name} is ", r2_score(pred,y_test))
     print(f"Mean absolute error for {name} is ", mean_absolute_error(pred,y_test))
     print()
# Out:
# Accuracy Score for Linear Regression is :  68.9407116055899 %
# R_square score for Linear Regression is  0.5423162481703736
# Mean absolute error for Linear Regression is  2627.6178419145194
#
# Accuracy Score for Lasso is :  68.92993969805231 %
# R_square score for Lasso is  0.5408551027506547
# Mean absolute error for Lasso is  2627.535664945439
#
# Accuracy Score for XGBRFRegressor is :  67.1425221089843 %
# R_square score for XGBRFRegressor is  0.42787685950371646
# Mean absolute error for XGBRFRegressor is  2394.709161931818
#
# Accuracy Score for RandomForest is :  79.09344415198866 %
# R_square score for RandomForest is  0.7113591530911934
# Mean absolute error for RandomForest is  1176.111111111111

# %% [markdown]
# ###  MAKING LABEL FOR PREMIUM AND RUNNING MODELS

# %%
df=pd.get_dummies(data=df,columns=['PremiumLabel'])

# %%
df.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice  PremiumLabel_Low  PremiumLabel_Basic  \
# 0                       0         25000                 0                   1
# 1                       0         29000                 0                   0
# 2                       1         23000                 0                   1
# 3                       2         28000                 0                   0
# 4                       1         23000                 0                   1
#
#    PremiumLabel_Average  PremiumLabel_High  PremiumLabel_SuperHigh
# 0                     0                  0                       0
# 1                     1                  0                       0
# 2                     0                  0                       0
# 3                     1                  0                       0
# 4                     0                  0                       0

# %%
x1=df.drop('PremiumPrice',axis=1)
y1=df['PremiumPrice']

# %%
X_train,X_test,y_train,y_test = train_test_split(x1,y1,test_size=0.2,random_state=43)

# %%
models = {
    LinearRegression():'Linear Regression',
    Lasso():'Lasso',
    XGBRFRegressor():'XGBRFRegressor',
    RandomForestRegressor():'RandomForest'
}
for m in models.keys():
    m.fit(X_train,y_train)
# Out:
# [07:08:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
for model,name in models.items():
     print(f"Accuracy Score for {name} is : ",model.score(X_test,y_test)*100,"%")
     pred = model.predict(X_test)
     print(f"R_square score for {name} is ", r2_score(pred,y_test))
     print(f"Mean absolute error for {name} is ", mean_absolute_error(pred,y_test))
     print()
# Out:
# Accuracy Score for Linear Regression is :  98.56380001513672 %
# R_square score for Linear Regression is  0.9848369992757599
# Mean absolute error for Linear Regression is  589.4320717008245
#
# Accuracy Score for Lasso is :  98.55713226870688 %
# R_square score for Lasso is  0.984743960911669
# Mean absolute error for Lasso is  590.0852460054554
#
# Accuracy Score for XGBRFRegressor is :  95.73978027080742 %
# R_square score for XGBRFRegressor is  0.9481122444823208
# Mean absolute error for XGBRFRegressor is  923.3413283222853
#
# Accuracy Score for RandomForest is :  99.78196978713636 %
# R_square score for RandomForest is  0.9977444843418877
# Mean absolute error for RandomForest is  79.79797979797979
